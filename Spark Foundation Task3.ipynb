# %% [markdown]
# # Task 3 - Exploratory Data Analysis - Retail

# %% [markdown]
# Author: Pooja Parkar

# %% [markdown]
# Email-Id: poojaparkar1162@gmail.com

# %% [markdown]
# Linkedin : http://linkedin.com/in/pooja-parkar-4698081bb

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\Spider\Downloads\SampleSuperstore.csv")
dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
dataset.shape
# Out:
# (9994, 13)

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
dataset.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
dataset['City'].value_counts().head(10)
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Name: City, dtype: int64

# %%
dataset['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
dataset['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
dataset['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
dataset[['City','Profit']].max()
# Out:
# City         Yuma
# Profit    8399.98
# dtype: object

# %%
top_10_profit=dataset.sort_values(by='Profit',ascending=False).head(10)
top_10_profit
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 6826  Standard Class    Corporate  United States      Lafayette       Indiana
# 8153     First Class     Consumer  United States        Seattle    Washington
# 4190  Standard Class     Consumer  United States         Newark      Delaware
# 9039  Standard Class     Consumer  United States        Detroit      Michigan
# 4098  Standard Class     Consumer  United States    Minneapolis     Minnesota
# 2623     First Class  Home Office  United States  New York City      New York
# 509   Standard Class     Consumer  United States        Atlanta       Georgia
# 8488    Second Class     Consumer  United States      Arlington      Virginia
# 7666  Standard Class  Home Office  United States     Providence  Rhode Island
# 6520    Second Class     Consumer  United States        Jackson      Michigan
#
#       Postal Code   Region         Category Sub-Category      Sales  Quantity  \
# ...

# %%
corr=dataset.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot('Category',data=dataset)
# Out:
# C:\Users\Spider\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize=(20,15))
sns.countplot('Sub-Category',data=dataset,hue='Category')
# Out:
# C:\Users\Spider\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(x=dataset.State,order=(dataset.State.value_counts().head(10)).index)
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
sns.scatterplot(x='Category',y='Sales',data=dataset)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Sales'>

# %%
sns.scatterplot(x='Category',y='Profit',data=dataset,color='red')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Profit'>

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x='Sub-Category',y='Sales',data=dataset)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
plt.figure(figsize=(18,7))
sns.lineplot(x='Sub-Category',y='Quantity',data=dataset,legend='brief')
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Quantity'>

# %%
state=dataset.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
state[:20].plot(kind='bar',color=['green','blue'])
plt.title('Profit and Sales in top 20 states')
plt.xlabel('States')
plt.ylabel('Total profit/sales')
# Out:
# Text(0, 0.5, 'Total profit/sales')

# %%
sns.barplot(y='Discount',x='Category',data=dataset)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Discount'>

# %%
sns.countplot('Region',data=dataset)
# Out:
# C:\Users\Spider\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Sub-Category',y='Discount',data=dataset)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Discount'>

# %% [markdown]
# Maximum discounts has been given in the sub-category of binders and machines
